# %% [markdown]
# <a href="https://colab.research.google.com/github/Yana-Kryukova/ai-ml-ngtu/blob/main/Lectures%5Clecture_o1_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Лекция 1: Введение в искусственный интеллект для инженера-аэродинамика**
#
# **Дисциплина:** Системы искусственного интеллекта и машинное обучение
# **Лектор:** Крюкова Яна Сергеевна
# **Дата:** 10 февраля 2026 года

# %% [markdown]
# ## 🎯 Цели лекции

# %% [markdown]
# 1. **Понять**, почему методы ИИ становятся неотъемлемым инструментом современного инженера
# 2. **Разобраться** в основных терминах и понятиях: ИИ, ML, Data Science
# 3. **Узнать**, почему именно Python стал стандартом в ML и какую роль играет GitHub
# 4. **Увидеть** конкретные примеры применения ИИ в задачах гидроаэродинамики
# 5. **Познакомиться** со структурой курса и требованиями

# %% [markdown]
# ## ✈ План лекции

# %% [markdown]
# - Зачем инженеру ИИ? Интерактивный опрос
# - Основные понятия ИИ и ML
# - Почему Python? Что такое GitHub?
# - Примеры применения в аэродинамике
# - Структура курса и требования
# - Вопросы, практическое задание, итоги

# %% [markdown]
# ## 1. Зачем инженеру-аэродинамику искусственный интеллект?

# %% [markdown]
# ### 🎤 **Вопрос к аудитории:**
#
# "Кто из вас уже сталкивался с обработкой экспериментальных данных?
# Например, строил графики в Excel или обрабатывал результаты лабораторных работ?"

# %% [markdown]
# ### 📊 Реальные вызовы, с которыми вы столкнетесь:
#
# **Сценарий 1:** Вы провели 100 экспериментов в аэродинамической трубе.
# Каждый эксперимент — 20 параметров. Это 2000 чисел.
# Как найти закономерности?
#
# **Сценарий 2:** CFD-расчет одного варианта профиля занимает 8 часов.
# Нужно проанализировать 50 вариантов. Это 400 часов (16 дней!)
# Как ускорить процесс?
#
# **Сценарий 3:** У вас есть данные с 200 датчиков на крыле самолета
# в реальном времени. Как определить, что начинается срыв потока,
# чтобы вовремя скорректировать управление?

# %% [markdown]
# ### 🔍 Традиционные методы vs Новые возможности
#
# | Традиционные методы | Новые возможности с ИИ | Выгода для инженера |
# |-------------------|----------------------|-------------------|
# | Ручная обработка в Excel | **Автоматический анализ** тысяч строк данных | Экономия **часов** рутинной работы |
# | Эмпирические формулы из справочников | **Адаптивные модели**, обучающиеся на ваших данных | Точность **выше** для конкретных условий |
# | CFD-расчеты по нескольку часов | **Суррогатные модели** за секунды | Возможность анализа **сотен** вариантов |
# | Визуальный анализ графиков | **Автоматическое** выявление аномалий и трендов | Обнаружение **скрытых** закономерностей |
#
# **Ключевая мысль:** ИИ не заменяет классические методы, а **дополняет** их,
# расширяя возможности инженера. Это как получить новый измерительный прибор
# или вычислительный метод.

# %% [markdown]
# ## 2. Основные понятия: разбираемся в терминах

# %% [markdown]
# ### 🧠 Иерархия интеллектуальных систем
#
#
#
# ```
# Искусственный интеллект (ИИ)
# ├── Машинное обучение (ML - Machine Learning)
# │   ├── Глубокое обучение (DL - Deep Learning)
# │   └── Классические алгоритмы
# └── Обработка естественного языка, компьютерное зрение и др.
# ```

# %% [markdown]
# ![01.png](data:image/png;base64,...)

# %% [markdown]
# ### 📚 Определения для инженерного контекста
#
# **Искусственный интеллект (Artificial Intelligence, ИИ)**
# > *"Способность машины выполнять когнитивные функции, обычно ассоциируемые с человеческим разумом: обучение, решение задач, принятие решений"*
# >
# > **Для нас как инженеров:** Системы, которые могут "думать" как инженер:
# > анализировать данные, находить закономерности, оптимизировать параметры,
# > предсказывать поведение системы.
#
# **Машинное обучение (Machine Learning, ML)**
# > *"Раздел ИИ, изучающий алгоритмы, которые улучшают свою производительность
# > через опыт (данные), без явного программирования"*
# >
# > **Для нас:** Автоматическое выявление физических закономерностей
# > в результатах экспериментов и расчетов. Не мы пишем формулы,
# > а алгоритм находит их в данных.
#
# **Data Science (Наука о данных)**
# > *"Междисциплинарная область, использующая научные методы, процессы,
# > алгоритмы для извлечения знаний и insights из структурированных и
# > неструктурированных данных"*
# >
# > **Для нас:** Вся цепочка работы с инженерными данными:
# > от измерения в эксперименте → обработка → анализ → визуализация →
# > презентация результатов.

# %% [markdown]
# ### 🎤 **Вопрос к аудитории**
#
# "Приведите пример из вашего опыта или представьте ситуацию,
# где каждый из этих подходов мог бы быть полезен:
# 1. ИИ (автоматическое принятие решений)
# 2. ML (обучение на данных)
# 3. Data Science (комплексный анализ данных)

# %% [markdown]
# #### Например:
#
# * система стабилизации беспилотника,
# * анализ данных продувки,
# * прогноз расхода топлива.

# %% [markdown]
# ## 3. Почему именно Python? И что такое GitHub?

# %% [markdown]
# ### 🐍 Python: язык для инженеров и ученых
#
# **🎤 Вопрос:** "Кто уже программировал на Python? На других языках?
# Какой опыт?"
#
# #### Почему Python, а не MATLAB/Fortran/C++?
#
# | Критерий | Python | Альтернативы | Почему выбираем Python |
# |----------|--------|--------------|------------------------|
# | **Простота изучения** | 👍 Очень простой синтаксис | 👎 Сложнее | Быстрый старт для инженеров |
# | **Сообщество и библиотеки** | 👍 200,000+ пакетов | 👎 Ограничено | Готовые решения для любых задач |
# | **Бесплатность** | 👍 Полностью бесплатен | 👎 MATLAB дорогой | Доступно всем студентам |
# | **Интеграция** | 👍 Связь с любыми системами | 👎 Часто изолирован | Можно встроить в любую систему |
# | **Индустриальный стандарт** | 👍 Используют Google, NASA, SpaceX | 👎 Устаревающие технологии | Актуальные навыки для работы |
#
# #### Ключевые библиотеки, которые мы будем использовать:
#
# 1. **NumPy** — работа с массивами, матрицами (как MATLAB, но бесплатно)
# 2. **Pandas** — анализ табличных данных (мощнее Excel в 100 раз)
# 3. **Matplotlib/Seaborn** — профессиональные графики и визуализации
# 4. **Scikit-learn** — готовые алгоритмы машинного обучения
# 5. **TensorFlow/Keras** — нейронные сети и глубокое обучение
#
# **Пример кода для сравнения:**
# ```python
# # Python (напоминает математическую запись)
# подъемная_сила = масса * ускорение_свободного_падения
#
# # C++ (более сложно для начинающих)
# float lift_force = mass * GRAVITY;
# ```

# %% [markdown]
# ### 🐙 GitHub: ваш цифровой инженерный журнал
#
# **🎤 Вопрос:** "Кто слышал о Git или GitHub? Кто использовал?"
#
# #### Что такое Git и GitHub?
#
# **Git** — система контроля версий. Представьте, что это "машина времени" для вашего кода:
# - Сохраняет каждое изменение
# - Позволяет вернуться к любой версии
# - Показывает, что и когда было изменено
#
# **GitHub** — облачная платформа для хранения кода с использованием Git.
# Это как "Google Диск" для программистов, но с super-возможностями.
#
# #### Почему мы используем GitHub в курсе? 5 причин:
#
# 1. **📖 Порфолио ваших работ** — после курса у вас будет репозиторий с 8 завершенными проектами
# 2. **👨‍🏫 Проверка и обратная связь** — я смогу комментировать ваш код прямо в GitHub
# 3. **🤝 Коллаборация** — сможете работать в команде над проектами
# 4. **💼 Подготовка к работе** — 90% IT-компаний используют Git, это must-have навык
# 5. **🔒 Надежное хранение** — код не потеряется, если сломается компьютер
#
# #### Как это выглядит на практике:
#
# ```
# Ваш репозиторий на GitHub:
# AI_in_Aerodynamics_Ivanov/  (ваша фамилия)
# ├── lab_01_intro/           ← Папка с первой работой
# │   ├── analysis.ipynb      ← Ваш код в Colab
# │   └── results/            ← Графики и выводы
# ├── lab_02_data_preprocessing/
# ├── ...
# └── final_project/          ← Итоговый проект
# ```
#
# **Простая аналогия:** GitHub — это как чертежная доска инженера,
# где вы ведете все расчеты, а Git — это возможность сохранять
# каждую версию чертежа и возвращаться к ней.

# %% [markdown]
# ## 4. Как ИИ помогает решать практические задачи аэродинамики?

# %% [markdown]
# ### 🎯 Три уровня применения (от простого к сложному)
#
# #### Уровень 1: Анализ и предсказание (с этого начнем мы)
#
# **Пример 1: Предсказание аэродинамических коэффициентов**
#
# ```python
# # ТРАДИЦИОННО (формула из учебника):
# # C_y = 2π * α (для малых углов, идеальная жидкость...)
# # Проблема: реальность сложнее формул!
#
# # С МАШИННЫМ ОБУЧЕНИЕМ:
# # Алгоритм обучается на реальных экспериментальных данных
# # Вход: [α, число Маха, число Рейнольдса, геометрия профиля...]
# # Выход: C_y с учетом всех эффектов
# # Точность: 95-98% против 70-80% у упрощенных формул
# ```
#
# **Пример 2: Классификация режимов течения по датчикам**
#
# 🎤 **Мини-кейс для обсуждения (3 минуты):**
# "Представьте, что у вас есть данные с 20 датчиков давления
# на поверхности крыла. Как определить начало срыва потока?
# Какие признаки (features) могли бы указывать на срыв?"

# %% [markdown]
# ##### ML-подход:
# 1. Собираем данные при нормальном обтекании и при срыве
# 2. Алгоритм находит "отпечатки пальцев" каждого состояния
# 3. В реальном времени система отслеживает: "Сейчас данные
#    больше похожи на 'срыв' или 'нормальное течение'?"

# %% [markdown]
# #### Уровень 2: Ускорение расчетов (CFD + AI = суперсила)
#
# **Проблема:** Один CFD-расчёт профиля = 4-8 часов
# **Нужно:** Проанализировать 100 вариантов геометрии
# **Итого:** 400-800 часов (16-33 дня!) ❌
#
# **Решение со surrogate modeling:**
#
# 1. Делаем 10 детальных CFD-расчетов (40-80 часов)
# 2. Обучаем нейросеть на этих данных (2 часа обучения)
# 3. Нейросеть предсказывает результат для ЛЮБОГО профиля за 0.1 секунду!
# 4. Анализируем 1000 вариантов за 100 секунд вместо 8000 часов ✅
#
# **Точность:** 95-98% для ключевых параметров (C_y, C_x, C_m)
#
# #### Уровень 3: Интеллектуальное управление в реальном времени
#
# **Система активного управления обтеканием:**
# ```
# Датчики давления (1000 раз/сек)
#     → ML-модель (анализ в реальном времени)
#     → Исполнительные механименты (закрылки, micro-jets)
#     → Оптимальное обтекание
# ```
#
# **Реальные применения:**
# - Boeing 787: снижение сопротивления на 2-3%
# - Формула 1: активная аэродинамика для лучшего сцепления
# - Ветряные турбины: адаптация к изменяющемуся ветру

# %% [markdown]
# ## 5. Типы задач машинного обучения (на пальцах)

# %% [markdown]
# ### 🎤 **Интерактивное голосование:**
#
# "Как вы думаете, к какому типу относятся эти задачи?"
#
# 1. "По данным эксперимента предсказать C_y для нового угла атаки"
#    - А) Регрессия
#    - Б) Классификация
#    - В) Кластеризация
#
# 2. "Определить по датчикам, ламинарное течение или турбулентное"
#    - А) Регрессия
#    - Б) Классификация
#    - В) Кластеризация
#
# 3. "Разделить 1000 профилей на группы по похожим аэродинамическим свойствам"
#    - А) Регрессия
#    - Б) Классификация
#    - В) Кластеризация

# %% [markdown]
# #### *Правильные ответы:*
# 1-А, 2-Б, 3-В

# %% [markdown]
# ### 📈 Регрессия (Regression) — "СКОЛЬКО?"
# **Суть:** Предсказание числового значения
# **Формула:** `y = f(x)` где y — число
# **Примеры в аэродинамике:**
# - Прогноз коэффициента подъемной силы \( C_y \)
# - Оценка температуры поверхности при гиперзвуковом обтекании
# - Предсказание давления в определенной точке

# %% [markdown]
# ### 🎯 Классификация (Classification) — "ЧТО?"
# **Суть:** Отнесение объекта к одному из классов
# **Формула:** `класс = f(x)` где класс — категория
# **Примеры:**
# - Ламинарное / турбулентное / переходное течение
# - Наличие / отсутствие срыва потока
# - Тип вихревой структуры

# %% [markdown]
# ### 🧩 Кластеризация (Clustering) — "КАК СГРУППИРОВАТЬ?"
# **Суть:** Разделение данных на группы без заранее известных меток
# **Формула:** `группы = f(x)` где группы неизвестны заранее
# **Примеры:**
# - Выявление типичных режимов работы двигателя
# - Группировка профилей по аэродинамическим характеристикам
# - Обнаружение аномальных режимов течения

# %% [markdown]
# ## 6. Простейшая аналогия: как работает ML (без формул)

# %% [markdown]
# ### 👨‍🏫 Обучение как наставничество инженера-стажера
#
# **Этап 1: Подготовка "учебника" (обучающие данные)**
#
# Представьте, что вы — опытный инженер, а алгоритм — ваш стажер.
#
# Вы даете ему "учебник" — результаты 1000 экспериментов:
# ```
# Эксперимент 1: α=5°, V=50 м/с, профиль NACA0012 → C_y=0.8
# Эксперимент 2: α=10°, V=50 м/с, профиль NACA0012 → C_y=1.2
# ...
# Эксперимент 1000: α=15°, V=80 м/с, профиль NACA4415 → C_y=1.8
# ```
#
# **Этап 2: Обучение "стажера" (тренировка алгоритма)**
#
# Стажер (алгоритм) ищет закономерности:
# - "Когда угол α растет, C_y обычно увеличивается" ✅
# - "Для профиля NACA4415 рост C_y более интенсивный" ✅
# - "Если скорость больше 70 м/с, зависимость становится нелинейной" ✅
#
# **Этап 3: Экзамен (тестирование на новых данных)**
#
# Даем параметры, которых не было в "учебнике":
# - α=12°, V=65 м/с, профиль NACA23012
#
# Стажер думает:
# "Похоже на Эксперимент 450, но скорость выше...
# Похоже на Эксперимент 780, но угол меньше...
# Мой прогноз: C_y ≈ 1.45"
#
# **Этап 4: Проверка и улучшение**
#
# Делаем реальный эксперимент: C_y = 1.48
# Стажер ошибся на 0.03 → хороший результат!
# Запоминаем этот опыт → модель становится точнее.

# %% [markdown]
# ## 7. Структура курса: что нас ждет в семестре

# %% [markdown]
# ### 📅 Обзор 16 недель (1 семестр)
#
# ```python
# # БЛОК 1: ФУНДАМЕНТ (недели 1-6) - "Учимся ходить"
# # Тема: От данных к первым моделям
# ├── Неделя 1-2: Python + GitHub + анализ данных
# ├── Неделя 3-4: Линейная регрессия для инженерных задач
# └── Неделя 5-6: Классификация режимов течения
#
# # БЛОК 2: МОЩНЫЕ ИНСТРУМЕНТЫ (недели 7-12) - "Учимся бегать"
# # Тема: Современные методы ML
# ├── Неделя 7-8: Random Forest и анализ важности параметров
# ├── Неделя 9-10: Нейронные сети для сложных зависимостей
# └── Неделя 11-12: CNN для анализа изображений течений
#
# # БЛОК 3: РЕАЛЬНЫЙ ПРОЕКТ (недели 13-16) - "Строим самолет"
# # Тема: От идеи к работающему решению
# ├── Неделя 13-14: Работа над проектом
# ├── Неделя 15: Подготовка презентаций
# └── Неделя 16: Защита проектов и подведение итогов
# ```

# %% [markdown]
# ### 🛠️ Инструменты, которые мы освоим (постепенно!)
#
# **Неделя 1-2:**
# - Google Colab (запускаем код в браузере)
# - GitHub (храним и показываем работы)
# - Pandas (анализируем таблицы с экспериментами)
#
# **Неделя 3-6:**
# - Scikit-learn (первые ML-модели)
# - Matplotlib (профессиональные графики)
#
# **Неделя 7-12:**
# - TensorFlow/Keras (нейронные сети)
# - Продвинутые методы визуализации
#
# **🎤 Вопрос для обсуждения:**
# "Какой проект из области аэродинамики вам было бы интересно
# реализовать с помощью ML в конце курса?"

# %% [markdown]
# ## 8. Требования и система оценивания

# %% [markdown]
# ### ✅ Что нужно для успешного прохождения?
#
# **Технические требования (всё бесплатно!):**
# 1. Аккаунт Google → для Google Colab
# 2. Аккаунт GitHub → для хранения работ
# 3. Браузер Chrome/Firefox → для работы с Colab
# 4. Базовые знания Python (будем вспоминать вместе)
#
# **Организационные требования:**
# - 8 лабораторных работ (раз в две недели, 2-4 часа на каждую)
# - Итоговый проект (3-4 недели работы)
# - Активность на занятиях (вопросы, обсуждения)

# %% [markdown]
# ### 📊 Система оценивания (прозрачная и справедливая)
#
# | Компонент | Баллы | Что именно оценивается |
# |-----------|-------|-----------------------|
# | **Лабораторные 1-7** | 6*7 | Своевременность (2), полнота (2), качество кода (2) |
# | **Итоговый проект** | 41 | Сложность (10), реализация (20), презентация (11) |
# | **Активность** | 1*7 | Вопросы, помощь коллегам, feedback |
# | **Итого** | **100** | |
#
# **Пороги:**
# - **50+ баллов** → Зачет автоматом 🎉
# - **40-49 баллов** → Дополнительное задание или собеседование
# - **< 40 баллов** → Не зачет (редкий случай при выполнении работ)
#
# **Важный принцип:** Оценивается прогресс, а не только результат.
# Лучше сделать простую, но работающую модель, чем не сдать ничего!

# %% [markdown]
# ## 9. Практическое задание на следующую неделю

# %% [markdown]
# ### 🚀 Лабораторная работа 1: "Первый контакт с данными"
#
# **Цель:** Настроить рабочее окружение и выполнить первый анализ реальных данных
#
# **Что нужно сделать (по шагам):**
#
# 1. **Регистрация** (10 минут)
#    - Создать аккаунт на GitHub (если нет)
#    - Создать репозиторий: `AI_in_Aerodynamics_ВашаФамилия`
#
# 2. **Первые шаги в Colab** (30 минут)
#    - Открыть [стартовый ноутбук](https://colab.research.google.com/...) по ссылке
#    - Выполнить первые ячейки с примерами
#
# 3. **Анализ данных эксперимента** (60 минут)
#    - Данные: результаты продувки профиля NACA0012
#    - Параметры: угол атаки α (град.), C_y, C_x
#    - Задачи:
#      a) Построить график C_y(α)
#      b) Построить график C_x(α)
#      c) Найти угол атаки с максимальным аэродинамическим качеством K = C_y/C_x
#
# 4. **Оформление и сдача** (20 минут)
#    - Сохранить ноутбук в свой GitHub-репозиторий
#    - Добавить комментарии к коду
#    - Сделать выводы по результатам
#
# **🎤 Вопрос перед началом:**
# "Как вы думаете, какой будет вид зависимости C_y от α
# для симметричного профиля NACA0012? Линейный? Квадратичный?
# Другой? Запишите свою гипотезу, потом проверим!"
#
# **Срок сдачи:** 17 февраля

# %% [markdown]
# ## 10. Вдохновляющие примеры (чтобы понимать, к чему стремимся)

# %% [markdown]
# ### 🏎️ **Формула 1: AI для каждого круга**
# - За один уик-энд собирается **3 ТБ данных** (как 6000 фильмов!)
# - ML-модели в реальном времени анализируют:
#   - Износ шин
#   - Деградацию аэродинамики
#   - Оптимальную стратегию пит-стопов
# - Результат: **+0.15 с на круге** = разница между поул-позицией и 5-м местом

# %% [markdown]
# ### 🛫 **Airbus A350: predictive maintenance**
# - 6000+ датчиков на самолете
# - ML предсказывает отказы компонентов за **50-100 часов** до возникновения
# - Экономия: **$10M+ в год** на одном самолете за счет предотвращения задержек

# %% [markdown]
# ### 🌪️ **Метеорология: предсказание экстремальных явлений**
# - Суперкомпьютерные модели + ML для ускорения
# - Точность предсказания траектории урагана: **+20%** за 10 лет
# - Заблаговременность предупреждений: **+12 часов**

# %% [markdown]
# ### 🎤 **Финальный вопрос для размышления:**
# "Как вы думаете, через 5-10 лет изменится ли работа инженера-аэродинамика
# с появлением ИИ? Станет ли она проще или сложнее?
# Что останется чисто человеческой компетенцией?"

# %% [markdown]
# ## 📝 Ключевые выводы с лекции
#
# 1. **ИИ — это новый инструмент в инженерном арсенале**, как когда-то компьютер заменил логарифмическую линейку
# 2. **Python — lingua franca** современной data science, учить его необходимо
# 3. **GitHub — ваш инженерный журнал** и будущее портфолио
# 4. **Начинаем с простого**: первая модель может быть всего из 10 строк кода
# 5. **Курс построен на практике**: 80% времени будем программировать и экспериментировать
# 6. **Самое ценное — ваши идеи**: как применить ML к вашим будущим дипломным и научным работам

# %% [markdown]
# ## ❓ Вопросы для самопроверки (домашнее размышление)
#
# 1. **Для инженера:** В чем принципиальная разница между физической моделью
#    (например, уравнения Навье-Стокса) и ML-моделью, обученной на данных CFD?
#
# 2. **Для программиста:** Почему именно Python, а не MATLAB или Fortran,
#    стал стандартом в ML? Какие преимущества для инженерных расчетов?
#
# 3. **Для исследователя:** Какой тип задачи (регрессия/классификация/кластеризация)
#    вы бы выбрали для:
#    - Предсказания точки перехода ламинарного течения в турбулентное?
#    - Автоматической классификации типов вихревых структур на визуализациях?
#    - Группировки различных геометрий профилей по их аэродинамическим свойствам?
#
# 4. **Для практика:** Зачем инженеру GitHub, если можно хранить код на флешке
#    или в почте? Какие конкретные преимущества дает система контроля версий
#    в научной и инженерной работе?

# %% [markdown]
# ## 📚 Рекомендуемые материалы на первую неделю
#
# ### Для быстрого старта:
# 1. **Видео (15 мин):** ["Python за 15 минут для инженеров"](https://youtu.be/...)
#    - основы синтаксиса, которые нам понадобятся сразу
#
# 2. **Туториал (30 мин):** ["GitHub для начинающих"](https://guides.github.com/activities/hello-world/)
#    - создание первого репозитория
#
# 3. **Статья (10 мин):** ["Машинное обучение в аэродинамике: первые успехи"](https://arc.aiaa.org/doi/10.2514/1.J059254)
#    - обзор реальных применений
#
# ### Для углубленного изучения (по желанию):
# 4. **Книга (глава 1):** "Data-Driven Science and Engineering" (Brunton & Kutz)
# 5. **Курс:** ["Введение в Python для инженеров" на Stepik](https://stepik.org/course/58852)
# 6. **Документация:** [Официальный туториал по Google Colab](https://colab.research.google.com/notebooks/intro.ipynb)

# %% [markdown]
# ## 🆘 Где получить помощь?
#
#  **GitHub Issues:** В вашем репозитории
#    - Технические вопросы по коду
#    - Проблемы с настройкой
#
#
# **Девиз курса:** "Не бывает глупых вопросов, бывают неисследованные проблемы!"
#
# ---
#
# **Следующая лекция (24 февраля):**
# "Python для инженерных расчетов: от Excel к профессиональному анализу данных.
# NumPy, Pandas и искусство визуализации."
#
# *Готовьте вопросы по первой лабораторной!*
#
# ---
# *Лекция подготовлена: Крюкова Я.С., кафедра аэрогидродинамики НГТУ*
# *Февраль 2025*
# *Материалы доступны в репозитории курса: https://github.com/Yana-Kryukova/ai-ml-ngtu*
#
# *P.S. Помните: каждый эксперт когда-то был новичком.
# Главное — начать и не бояться делать ошибки!*
# ```
